# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
from pre_processing import *

# %%
product
# Out:
#      product_id  family_id  negocio_id  category_id  tier_id  \
# 0           881       1291          20          131        4
# 1           805       1224          20          131        3
# 2           892       1089          20          146        1
# 3           841       1224          20          131        3
# 4           830       1089          20          131        1
# ..          ...        ...         ...          ...      ...
# 932         786       1447          22          192        1
# 933         832       1447          22          192        3
# 934         848       1447          22          192        3
# 935         849       1447          22          192        2
# 936         933       1447          22          192        3
#
#      utilidad_bruta_transf
# 0                10.378017
# 1                10.177925
# 2                10.008243
# 3                 7.698362
# 4                 7.353678
# ..                     ...
# 932              -0.184480
# ...

# %%
customers_products = tf.constant(matrix.copy())
num_customers = customers_products.shape[0]

# %%
products_features =

# %%
get_product_similarity()
